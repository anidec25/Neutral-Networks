# %% [markdown]
# ## Optimizers
#
# 1. Gradient Descent: Batch GD, Mini Batch GD, Sochastic GD
# 2. Momentum based GD
# 3. NAG
# 4. AdaGrad (Adaptive Gradient)
# 5. RMS Prop
# 6. ADAM (Adaptive Moment Estimation)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
df = pd.read_csv('./data/Churn_Modelling.csv')

# %%
drop_cols = ['RowNumber','CustomerId','Surname']

df.drop(columns=drop_cols, inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'], drop_first=True)

# %%
X = df.drop(columns=['Exited'])
y = df['Exited']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()

X_train_scaled = scalar.fit_transform(X_train)
X_test_scaled = scalar.transform(X_test)

# %% [markdown]
# ## Model Building

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(11, activation = 'relu', input_dim = 11))
model.add(Dense(11,activation = 'relu'))
model.add(Dense(11, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 11)                132
#
#  dense_1 (Dense)             (None, 11)                132
#
#  dense_2 (Dense)             (None, 11)                132
#
#  dense_3 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 408
# Trainable params: 408
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Playing with different optimizers

# %%
optimizers = tf.keras.optimizers.SGD(
    learning_rate=0.01,
    momentum=0.0
    )

# %%
model.compile(loss='binary_crossentropy', optimizer=optimizers, metrics=['accuracy'])

# %%
history = model.fit(X_train_scaled,y_train, epochs=100, validation_split= 0.2)
# Out:
# Epoch 1/100
# 2023-05-12 21:14:15.264730: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 200/200 [==============================] - 0s 909us/step - loss: 0.5693 - accuracy: 0.7972 - val_loss: 0.5435 - val_accuracy: 0.7975
# Epoch 2/100
# 200/200 [==============================] - 0s 452us/step - loss: 0.5327 - accuracy: 0.7972 - val_loss: 0.5210 - val_accuracy: 0.7975
# Epoch 3/100
# 200/200 [==============================] - 0s 439us/step - loss: 0.5154 - accuracy: 0.7972 - val_loss: 0.5070 - val_accuracy: 0.7975
# Epoch 4/100
# 200/200 [==============================] - 0s 441us/step - loss: 0.5042 - accuracy: 0.7972 - val_loss: 0.4971 - val_accuracy: 0.7975
# Epoch 5/100
# 200/200 [==============================] - 0s 442us/step - loss: 0.4958 - accuracy: 0.7972 - val_loss: 0.4894 - val_accuracy: 0.7975
# Epoch 6/100
# 200/200 [==============================] - 0s 427us/step - loss: 0.4887 - accuracy: 0.7972 - val_loss: 0.4823 - val_accuracy: 0.7975
# Epoch 7/100
# 200/200 [==============================] - 0s 429us/step - loss: 0.4822 - accuracy: 0.7972 - val_loss: 0.4757 - val_accuracy: 0.7975
# Epoch 8/100
# 200/200 [==============================] - 0s 477us/step - loss: 0.4761 - accuracy: 0.7972 - val_loss: 0.4690 - val_accuracy: 0.7975
# Epoch 9/100
# 200/200 [==============================] - 0s 441us/step - loss: 0.4699 - accuracy: 0.7972 - val_loss: 0.4625 - val_accuracy: 0.7975
# Epoch 10/100
# 200/200 [==============================] - 0s 431us/step - loss: 0.4640 - accuracy: 0.7972 - val_loss: 0.4562 - val_accuracy: 0.7975
# Epoch 11/100
# 200/200 [==============================] - 0s 424us/step - loss: 0.4581 - accuracy: 0.7975 - val_loss: 0.4499 - val_accuracy: 0.7975
# Epoch 12/100
# 200/200 [==============================] - 0s 423us/step - loss: 0.4523 - accuracy: 0.7995 - val_loss: 0.4442 - val_accuracy: 0.7994
# Epoch 13/100
# 200/200 [==============================] - 0s 422us/step - loss: 0.4470 - accuracy: 0.8012 - val_loss: 0.4388 - val_accuracy: 0.8012
# Epoch 14/100
# 200/200 [==============================] - 0s 425us/step - loss: 0.4420 - accuracy: 0.8037 - val_loss: 0.4339 - val_accuracy: 0.8056
# Epoch 15/100
# 200/200 [==============================] - 0s 428us/step - loss: 0.4373 - accuracy: 0.8070 - val_loss: 0.4297 - val_accuracy: 0.8037
# Epoch 16/100
# 200/200 [==============================] - 0s 433us/step - loss: 0.4332 - accuracy: 0.8095 - val_loss: 0.4262 - val_accuracy: 0.8087
# Epoch 17/100
# 200/200 [==============================] - 0s 422us/step - loss: 0.4297 - accuracy: 0.8100 - val_loss: 0.4235 - val_accuracy: 0.8125
# Epoch 18/100
# 200/200 [==============================] - 0s 422us/step - loss: 0.4268 - accuracy: 0.8122 - val_loss: 0.4207 - val_accuracy: 0.8144
# Epoch 19/100
# 200/200 [==============================] - 0s 420us/step - loss: 0.4242 - accuracy: 0.8127 - val_loss: 0.4182 - val_accuracy: 0.8144
# Epoch 20/100
# 200/200 [==============================] - 0s 427us/step - loss: 0.4217 - accuracy: 0.8161 - val_loss: 0.4161 - val_accuracy: 0.8169
# Epoch 21/100
# 200/200 [==============================] - 0s 460us/step - loss: 0.4193 - accuracy: 0.8181 - val_loss: 0.4142 - val_accuracy: 0.8225
# Epoch 22/100
# 200/200 [==============================] - 0s 422us/step - loss: 0.4171 - accuracy: 0.8195 - val_loss: 0.4125 - val_accuracy: 0.8219
# Epoch 23/100
# 200/200 [==============================] - 0s 421us/step - loss: 0.4153 - accuracy: 0.8213 - val_loss: 0.4108 - val_accuracy: 0.8206
# Epoch 24/100
# 200/200 [==============================] - 0s 416us/step - loss: 0.4133 - accuracy: 0.8239 - val_loss: 0.4091 - val_accuracy: 0.8219
# Epoch 25/100
# 200/200 [==============================] - 0s 535us/step - loss: 0.4114 - accuracy: 0.8245 - val_loss: 0.4074 - val_accuracy: 0.8206
# Epoch 26/100
# 200/200 [==============================] - 0s 439us/step - loss: 0.4095 - accuracy: 0.8267 - val_loss: 0.4059 - val_accuracy: 0.8213
# Epoch 27/100
# 200/200 [==============================] - 0s 451us/step - loss: 0.4074 - accuracy: 0.8288 - val_loss: 0.4041 - val_accuracy: 0.8213
# Epoch 28/100
# 200/200 [==============================] - 0s 431us/step - loss: 0.4052 - accuracy: 0.8298 - val_loss: 0.4024 - val_accuracy: 0.8225
# Epoch 29/100
# 200/200 [==============================] - 0s 430us/step - loss: 0.4030 - accuracy: 0.8322 - val_loss: 0.4006 - val_accuracy: 0.8225
# Epoch 30/100
# 200/200 [==============================] - 0s 423us/step - loss: 0.4007 - accuracy: 0.8330 - val_loss: 0.3987 - val_accuracy: 0.8263
# Epoch 31/100
# 200/200 [==============================] - 0s 430us/step - loss: 0.3983 - accuracy: 0.8328 - val_loss: 0.3978 - val_accuracy: 0.8263
# Epoch 32/100
# 200/200 [==============================] - 0s 441us/step - loss: 0.3958 - accuracy: 0.8364 - val_loss: 0.3954 - val_accuracy: 0.8288
# Epoch 33/100
# 200/200 [==============================] - 0s 429us/step - loss: 0.3933 - accuracy: 0.8356 - val_loss: 0.3934 - val_accuracy: 0.8319
# Epoch 34/100
# 200/200 [==============================] - 0s 419us/step - loss: 0.3905 - accuracy: 0.8394 - val_loss: 0.3925 - val_accuracy: 0.8294
# Epoch 35/100
# 200/200 [==============================] - 0s 426us/step - loss: 0.3880 - accuracy: 0.8414 - val_loss: 0.3895 - val_accuracy: 0.8325
# Epoch 36/100
# 200/200 [==============================] - 0s 441us/step - loss: 0.3854 - accuracy: 0.8431 - val_loss: 0.3876 - val_accuracy: 0.8350
# Epoch 37/100
# 200/200 [==============================] - 0s 508us/step - loss: 0.3829 - accuracy: 0.8444 - val_loss: 0.3849 - val_accuracy: 0.8363
# Epoch 38/100
# 200/200 [==============================] - 0s 443us/step - loss: 0.3801 - accuracy: 0.8466 - val_loss: 0.3824 - val_accuracy: 0.8388
# Epoch 39/100
# 200/200 [==============================] - 0s 409us/step - loss: 0.3772 - accuracy: 0.8469 - val_loss: 0.3799 - val_accuracy: 0.8394
# Epoch 40/100
# 200/200 [==============================] - 0s 445us/step - loss: 0.3744 - accuracy: 0.8483 - val_loss: 0.3782 - val_accuracy: 0.8406
# Epoch 41/100
# 200/200 [==============================] - 0s 457us/step - loss: 0.3720 - accuracy: 0.8497 - val_loss: 0.3741 - val_accuracy: 0.8419
# Epoch 42/100
# 200/200 [==============================] - 0s 420us/step - loss: 0.3689 - accuracy: 0.8520 - val_loss: 0.3731 - val_accuracy: 0.8444
# Epoch 43/100
# 200/200 [==============================] - 0s 456us/step - loss: 0.3662 - accuracy: 0.8523 - val_loss: 0.3700 - val_accuracy: 0.8431
# Epoch 44/100
# 200/200 [==============================] - 0s 421us/step - loss: 0.3638 - accuracy: 0.8534 - val_loss: 0.3661 - val_accuracy: 0.8425
# Epoch 45/100
# 200/200 [==============================] - 0s 428us/step - loss: 0.3612 - accuracy: 0.8542 - val_loss: 0.3633 - val_accuracy: 0.8438
# Epoch 46/100
# 200/200 [==============================] - 0s 424us/step - loss: 0.3581 - accuracy: 0.8562 - val_loss: 0.3609 - val_accuracy: 0.8462
# Epoch 47/100
# 200/200 [==============================] - 0s 417us/step - loss: 0.3556 - accuracy: 0.8570 - val_loss: 0.3588 - val_accuracy: 0.8481
# Epoch 48/100
# 200/200 [==============================] - 0s 420us/step - loss: 0.3532 - accuracy: 0.8564 - val_loss: 0.3568 - val_accuracy: 0.8469
# Epoch 49/100
# 200/200 [==============================] - 0s 458us/step - loss: 0.3510 - accuracy: 0.8572 - val_loss: 0.3551 - val_accuracy: 0.8500
# Epoch 50/100
# 200/200 [==============================] - 0s 427us/step - loss: 0.3489 - accuracy: 0.8591 - val_loss: 0.3529 - val_accuracy: 0.8525
# Epoch 51/100
# 200/200 [==============================] - 0s 426us/step - loss: 0.3470 - accuracy: 0.8581 - val_loss: 0.3522 - val_accuracy: 0.8506
# Epoch 52/100
# 200/200 [==============================] - 0s 420us/step - loss: 0.3454 - accuracy: 0.8606 - val_loss: 0.3510 - val_accuracy: 0.8537
# Epoch 53/100
# 200/200 [==============================] - 0s 402us/step - loss: 0.3441 - accuracy: 0.8612 - val_loss: 0.3498 - val_accuracy: 0.8537
# Epoch 54/100
# 200/200 [==============================] - 0s 401us/step - loss: 0.3426 - accuracy: 0.8628 - val_loss: 0.3493 - val_accuracy: 0.8556
# Epoch 55/100
# 200/200 [==============================] - 0s 407us/step - loss: 0.3411 - accuracy: 0.8631 - val_loss: 0.3481 - val_accuracy: 0.8550
# Epoch 56/100
# 200/200 [==============================] - 0s 407us/step - loss: 0.3405 - accuracy: 0.8630 - val_loss: 0.3490 - val_accuracy: 0.8500
# Epoch 57/100
# 200/200 [==============================] - 0s 409us/step - loss: 0.3394 - accuracy: 0.8637 - val_loss: 0.3491 - val_accuracy: 0.8500
# Epoch 58/100
# 200/200 [==============================] - 0s 407us/step - loss: 0.3386 - accuracy: 0.8637 - val_loss: 0.3477 - val_accuracy: 0.8537
# Epoch 59/100
# 200/200 [==============================] - 0s 405us/step - loss: 0.3375 - accuracy: 0.8636 - val_loss: 0.3508 - val_accuracy: 0.8512
# Epoch 60/100
# 200/200 [==============================] - 0s 405us/step - loss: 0.3373 - accuracy: 0.8642 - val_loss: 0.3467 - val_accuracy: 0.8544
# Epoch 61/100
# 200/200 [==============================] - 0s 414us/step - loss: 0.3365 - accuracy: 0.8636 - val_loss: 0.3482 - val_accuracy: 0.8512
# Epoch 62/100
# 200/200 [==============================] - 0s 408us/step - loss: 0.3363 - accuracy: 0.8650 - val_loss: 0.3471 - val_accuracy: 0.8525
# Epoch 63/100
# 200/200 [==============================] - 0s 407us/step - loss: 0.3354 - accuracy: 0.8642 - val_loss: 0.3461 - val_accuracy: 0.8550
# Epoch 64/100
# 200/200 [==============================] - 0s 409us/step - loss: 0.3349 - accuracy: 0.8644 - val_loss: 0.3472 - val_accuracy: 0.8544
# Epoch 65/100
# 200/200 [==============================] - 0s 467us/step - loss: 0.3349 - accuracy: 0.8659 - val_loss: 0.3464 - val_accuracy: 0.8544
# Epoch 66/100
# 200/200 [==============================] - 0s 488us/step - loss: 0.3341 - accuracy: 0.8639 - val_loss: 0.3463 - val_accuracy: 0.8544
# Epoch 67/100
# 200/200 [==============================] - 0s 422us/step - loss: 0.3339 - accuracy: 0.8648 - val_loss: 0.3458 - val_accuracy: 0.8519
# Epoch 68/100
# 200/200 [==============================] - 0s 448us/step - loss: 0.3339 - accuracy: 0.8630 - val_loss: 0.3462 - val_accuracy: 0.8537
# Epoch 69/100
# 200/200 [==============================] - 0s 417us/step - loss: 0.3332 - accuracy: 0.8652 - val_loss: 0.3456 - val_accuracy: 0.8550
# Epoch 70/100
# 200/200 [==============================] - 0s 406us/step - loss: 0.3330 - accuracy: 0.8642 - val_loss: 0.3475 - val_accuracy: 0.8537
# Epoch 71/100
# 200/200 [==============================] - 0s 407us/step - loss: 0.3329 - accuracy: 0.8653 - val_loss: 0.3450 - val_accuracy: 0.8562
# Epoch 72/100
# 200/200 [==============================] - 0s 407us/step - loss: 0.3326 - accuracy: 0.8641 - val_loss: 0.3458 - val_accuracy: 0.8519
# Epoch 73/100
# 200/200 [==============================] - 0s 432us/step - loss: 0.3325 - accuracy: 0.8645 - val_loss: 0.3453 - val_accuracy: 0.8537
# Epoch 74/100
# 200/200 [==============================] - 0s 472us/step - loss: 0.3325 - accuracy: 0.8652 - val_loss: 0.3469 - val_accuracy: 0.8525
# Epoch 75/100
# 200/200 [==============================] - 0s 417us/step - loss: 0.3323 - accuracy: 0.8650 - val_loss: 0.3469 - val_accuracy: 0.8512
# Epoch 76/100
# 200/200 [==============================] - 0s 418us/step - loss: 0.3319 - accuracy: 0.8653 - val_loss: 0.3493 - val_accuracy: 0.8494
# Epoch 77/100
# 200/200 [==============================] - 0s 453us/step - loss: 0.3320 - accuracy: 0.8647 - val_loss: 0.3456 - val_accuracy: 0.8531
# Epoch 78/100
# 200/200 [==============================] - 0s 406us/step - loss: 0.3317 - accuracy: 0.8652 - val_loss: 0.3457 - val_accuracy: 0.8494
# Epoch 79/100
# 200/200 [==============================] - 0s 431us/step - loss: 0.3313 - accuracy: 0.8636 - val_loss: 0.3459 - val_accuracy: 0.8525
# Epoch 80/100
# 200/200 [==============================] - 0s 433us/step - loss: 0.3314 - accuracy: 0.8655 - val_loss: 0.3454 - val_accuracy: 0.8544
# Epoch 81/100
# 200/200 [==============================] - 0s 452us/step - loss: 0.3314 - accuracy: 0.8644 - val_loss: 0.3455 - val_accuracy: 0.8544
# Epoch 82/100
# 200/200 [==============================] - 0s 413us/step - loss: 0.3314 - accuracy: 0.8633 - val_loss: 0.3454 - val_accuracy: 0.8537
# Epoch 83/100
# 200/200 [==============================] - 0s 405us/step - loss: 0.3311 - accuracy: 0.8658 - val_loss: 0.3462 - val_accuracy: 0.8462
# Epoch 84/100
# 200/200 [==============================] - 0s 406us/step - loss: 0.3309 - accuracy: 0.8661 - val_loss: 0.3458 - val_accuracy: 0.8525
# Epoch 85/100
# 200/200 [==============================] - 0s 426us/step - loss: 0.3307 - accuracy: 0.8661 - val_loss: 0.3458 - val_accuracy: 0.8500
# Epoch 86/100
# 200/200 [==============================] - 0s 440us/step - loss: 0.3307 - accuracy: 0.8642 - val_loss: 0.3452 - val_accuracy: 0.8519
# Epoch 87/100
# 200/200 [==============================] - 0s 413us/step - loss: 0.3306 - accuracy: 0.8661 - val_loss: 0.3452 - val_accuracy: 0.8519
# Epoch 88/100
# 200/200 [==============================] - 0s 404us/step - loss: 0.3306 - accuracy: 0.8648 - val_loss: 0.3459 - val_accuracy: 0.8506
# Epoch 89/100
# 200/200 [==============================] - 0s 409us/step - loss: 0.3303 - accuracy: 0.8659 - val_loss: 0.3461 - val_accuracy: 0.8525
# Epoch 90/100
# 200/200 [==============================] - 0s 492us/step - loss: 0.3303 - accuracy: 0.8650 - val_loss: 0.3450 - val_accuracy: 0.8531
# Epoch 91/100
# 200/200 [==============================] - 0s 408us/step - loss: 0.3297 - accuracy: 0.8670 - val_loss: 0.3451 - val_accuracy: 0.8550
# Epoch 92/100
# 200/200 [==============================] - 0s 409us/step - loss: 0.3303 - accuracy: 0.8666 - val_loss: 0.3451 - val_accuracy: 0.8544
# Epoch 93/100
# 200/200 [==============================] - 0s 406us/step - loss: 0.3296 - accuracy: 0.8667 - val_loss: 0.3454 - val_accuracy: 0.8519
# Epoch 94/100
# 200/200 [==============================] - 0s 404us/step - loss: 0.3297 - accuracy: 0.8686 - val_loss: 0.3441 - val_accuracy: 0.8562
# Epoch 95/100
# 200/200 [==============================] - 0s 412us/step - loss: 0.3298 - accuracy: 0.8669 - val_loss: 0.3442 - val_accuracy: 0.8569
# Epoch 96/100
# 200/200 [==============================] - 0s 410us/step - loss: 0.3297 - accuracy: 0.8653 - val_loss: 0.3452 - val_accuracy: 0.8506
# Epoch 97/100
# 200/200 [==============================] - 0s 437us/step - loss: 0.3298 - accuracy: 0.8669 - val_loss: 0.3449 - val_accuracy: 0.8569
# Epoch 98/100
# 200/200 [==============================] - 0s 414us/step - loss: 0.3294 - accuracy: 0.8670 - val_loss: 0.3456 - val_accuracy: 0.8525
# Epoch 99/100
# 200/200 [==============================] - 0s 412us/step - loss: 0.3296 - accuracy: 0.8659 - val_loss: 0.3446 - val_accuracy: 0.8525
# Epoch 100/100
# 200/200 [==============================] - 0s 404us/step - loss: 0.3292 - accuracy: 0.8675 - val_loss: 0.3446 - val_accuracy: 0.8519

# %%
y_log = model.predict(X_test_scaled)
y_pred = np.where(y_log > 0.5, 1, 0)


from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 63/63 [==============================] - 0s 336us/step
# 0.862

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'],label = 'Train Loss')
plt.plot(history.history['val_loss'], label= 'Test Loss')
plt.legend()

# %% [markdown]
# ### Momentum Based

# %%
def momemtum_based_gd(lr, m):
    """
    This function trains the model and print the accuracy and loss plot
    Input: Learining rate: 'Default value is  0.01'
           Momentum Value: 'Higher value means less weighted to past values'
    """
    model = Sequential()
    model.add(Dense(11, activation = 'relu', input_dim = 11))
    model.add(Dense(11,activation = 'relu'))
    model.add(Dense(11, activation = 'relu'))
    model.add(Dense(1, activation = 'sigmoid'))


    optimizers = tf.keras.optimizers.SGD(
        learning_rate=lr,
        momentum=m
        )

    model.compile(loss='binary_crossentropy', optimizer=optimizers, metrics=['accuracy'])

    history = model.fit(X_train_scaled,y_train, epochs=40, validation_split= 0.2, verbose=False)

    y_log = model.predict(X_test_scaled)
    y_pred = np.where(y_log > 0.5, 1, 0)

    print(accuracy_score(y_test,y_pred))


    plt.title(f'Momentum Based GD: momenturm {m}')
    plt.plot(history.history['loss'],label = 'Train Loss')
    plt.plot(history.history['val_loss'], label= 'Test Loss')
    plt.legend()
    plt.show()


## Driver code

m = [0.01,0.10,0.60,0.90,0.95,0.99]

for i in m:
    momemtum_based_gd(lr = 0.01, m = i)
# Out:
# 63/63 [==============================] - 0s 325us/step
# 0.8515
# 63/63 [==============================] - 0s 305us/step
# 0.859
# 63/63 [==============================] - 0s 319us/step
# 0.857
# 63/63 [==============================] - 0s 318us/step
# 0.8605
# 63/63 [==============================] - 0s 303us/step
# 0.854
# 63/63 [==============================] - 0s 307us/step
# 0.8395

# %% [markdown]
# ### Importing all the required library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# Performing EDA

# %%
## Is there any relation between exit (Target) wrt to gender


sns.countplot(x = df['Gender'], hue = df['Exited'])

print(df.groupby(by='Gender')['Gender'].count())
# Out:
# Gender
# Female    4543
# Male      5457
# Name: Gender, dtype: int64

# %%
sns.scatterplot(data=df , x='CreditScore' , y = 'Age', hue='Exited')
# Out:
# <Axes: xlabel='CreditScore', ylabel='Age'>

# %%
sns.scatterplot(data=df , x='CreditScore' , y = 'Balance', hue='Exited')
# Out:
# <Axes: xlabel='CreditScore', ylabel='Balance'>

# %%
sns.scatterplot(data=df , x='Tenure' , y = 'Age', hue='Exited')
# Out:
# <Axes: xlabel='Tenure', ylabel='Age'>

# %%
sns.scatterplot(data=df , x='EstimatedSalary' , y = 'Age', hue='Exited')
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Age'>

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.drop(columns='RowNumber', inplace=True)

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0          0.00              1          1               1        101348.88
# 1      83807.86              1          0               1        112542.58
# 2     159660.80              3          1               0        113931.57
# 3          0.00              2          0               0         93826.63
# 4     125510.82              1          1               1         79084.10
# ...         ...            ...        ...             ...              ...
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 0          1
# 1          0
# 2          1
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       1
# 9998       1
# 9999       0
#
# [10000 rows x 13 columns]

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'], drop_first=True)

# %%
df.drop(columns=['CustomerId','Surname'], inplace=True)

# %%
X = df.drop(columns='Exited')
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
                                                    X,
                                                    y,
                                                    test_size=0.33,
                                                    random_state=42
                                                    )

# %%
print(f'Shape of the original X: {X.shape}')
print(f'Shape of X-Train: {X_train.shape}')
print(f'Shape of X-Test: {X_test.shape}')


print("---------------------------------")

print(f'Shape of the original y: {y.shape}')
print(f'Shape of y-Train: {y_train.shape}')
print(f'Shape of y-Test: {y_test.shape}')
# Out:
# Shape of the original X: (10000, 11)
# Shape of X-Train: (6700, 11)
# Shape of X-Test: (3300, 11)
# ---------------------------------
# Shape of the original y: (10000,)
# Shape of y-Train: (6700,)
# Shape of y-Test: (3300,)

# %%
from sklearn.preprocessing import StandardScaler


std = StandardScaler()

X_train_scaled = std.fit_transform(X_train)
X_test_scaled = std.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.67588802, -0.94183739,  0.00934296, ...,  1.74875572,
#         -0.57987798, -1.10022343],
#        [ 0.30320673, -0.17987213,  1.04687659, ...,  1.74875572,
#         -0.57987798,  0.9089063 ],
#        [-0.10235819,  0.96307575, -0.33650158, ...,  1.74875572,
#         -0.57987798,  0.9089063 ],
#        ...,
#        [ 0.86475817, -0.08462648, -1.37403521, ..., -0.57183516,
#         -0.57987798, -1.10022343],
#        [ 0.15761932,  0.39160181,  1.04687659, ..., -0.57183516,
#         -0.57987798,  0.9089063 ],
#        [ 0.46959234,  1.15356706, -1.37403521, ...,  1.74875572,
#         -0.57987798,  0.9089063 ]])

# %% [markdown]
# ## ANN Model

# %%
import tensorflow
from tensorflow import keras
from tensorflow.python.keras import Sequential, callbacks
from tensorflow.python.keras.layers import Dense,Dropout
from tensorflow.python.keras.layers import Batch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[98], line 5
#       3 from tensorflow.python.keras import Sequential, callbacks
#       4 from tensorflow.python.keras.layers import Dense,Dropout
# ----> 5 from tensorflow.python.keras.layers import BatchNormalization
#
# ImportError: cannot import name 'BatchNormalization' from 'tensorflow.python.keras.layers' (/Users/aryan/miniconda3/envs/adv_ds/lib/python3.10/site-packages/tensorflow/python/keras/layers/__init__.py)

# %%
model = Sequential(name='Model_1')
model.add(Dense(10, activation='relu', input_dim = 11))
model.add(Dense(10,activation='relu'))
model.add(Dense(5,activation='relu'))
model.add(Dense(5,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "Model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 10)                120
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_26 (Dense)             (None, 5)                 55
# _________________________________________________________________
# dense_27 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 321
# Trainable params: 321
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

# %%
# my_callbacks = [
#     callbacks.EarlyStopping(monitor="val_loss",
#     min_delta=0,
#     patience=300,
#     verbose=0,
#     mode="auto",
#     baseline=None,
#     restore_best_weights=False)
# ]

history = model.fit(X_train_scaled,y_train, epochs=100, validation_split= 0.2)
# Out:
# Epoch 1/100
# 168/168 [==============================] - 0s 649us/step - loss: 0.3084 - accuracy: 0.8735 - val_loss: 0.3654 - val_accuracy: 0.8567
# Epoch 2/100
# 168/168 [==============================] - 0s 576us/step - loss: 0.3095 - accuracy: 0.8688 - val_loss: 0.3676 - val_accuracy: 0.8545
# Epoch 3/100
# 168/168 [==============================] - 0s 541us/step - loss: 0.3095 - accuracy: 0.8733 - val_loss: 0.3598 - val_accuracy: 0.8634
# Epoch 4/100
# 168/168 [==============================] - 0s 528us/step - loss: 0.3092 - accuracy: 0.8701 - val_loss: 0.3674 - val_accuracy: 0.8522
# Epoch 5/100
# 168/168 [==============================] - 0s 530us/step - loss: 0.3102 - accuracy: 0.8662 - val_loss: 0.3683 - val_accuracy: 0.8515
# Epoch 6/100
# 168/168 [==============================] - 0s 645us/step - loss: 0.3091 - accuracy: 0.8703 - val_loss: 0.3622 - val_accuracy: 0.8634
# Epoch 7/100
# 168/168 [==============================] - 0s 535us/step - loss: 0.3095 - accuracy: 0.8688 - val_loss: 0.3643 - val_accuracy: 0.8664
# Epoch 8/100
# 168/168 [==============================] - 0s 532us/step - loss: 0.3091 - accuracy: 0.8692 - val_loss: 0.3625 - val_accuracy: 0.8582
# Epoch 9/100
# 168/168 [==============================] - 0s 543us/step - loss: 0.3095 - accuracy: 0.8670 - val_loss: 0.3655 - val_accuracy: 0.8612
# Epoch 10/100
# 168/168 [==============================] - 0s 528us/step - loss: 0.3087 - accuracy: 0.8707 - val_loss: 0.3671 - val_accuracy: 0.8604
# Epoch 11/100
# 168/168 [==============================] - 0s 536us/step - loss: 0.3085 - accuracy: 0.8683 - val_loss: 0.3702 - val_accuracy: 0.8500
# Epoch 12/100
# 168/168 [==============================] - 0s 535us/step - loss: 0.3096 - accuracy: 0.8690 - val_loss: 0.3637 - val_accuracy: 0.8642
# Epoch 13/100
# 168/168 [==============================] - 0s 539us/step - loss: 0.3090 - accuracy: 0.8726 - val_loss: 0.3655 - val_accuracy: 0.8604
# Epoch 14/100
# 168/168 [==============================] - 0s 534us/step - loss: 0.3090 - accuracy: 0.8720 - val_loss: 0.3614 - val_accuracy: 0.8612
# Epoch 15/100
# 168/168 [==============================] - 0s 532us/step - loss: 0.3077 - accuracy: 0.8701 - val_loss: 0.3693 - val_accuracy: 0.8612
# Epoch 16/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3090 - accuracy: 0.8677 - val_loss: 0.3656 - val_accuracy: 0.8612
# Epoch 17/100
# 168/168 [==============================] - 0s 527us/step - loss: 0.3088 - accuracy: 0.8722 - val_loss: 0.3617 - val_accuracy: 0.8634
# Epoch 18/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3094 - accuracy: 0.8700 - val_loss: 0.3683 - val_accuracy: 0.8500
# Epoch 19/100
# 168/168 [==============================] - 0s 522us/step - loss: 0.3091 - accuracy: 0.8696 - val_loss: 0.3620 - val_accuracy: 0.8664
# Epoch 20/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3098 - accuracy: 0.8698 - val_loss: 0.3651 - val_accuracy: 0.8634
# Epoch 21/100
# 168/168 [==============================] - 0s 533us/step - loss: 0.3086 - accuracy: 0.8687 - val_loss: 0.3663 - val_accuracy: 0.8575
# Epoch 22/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3073 - accuracy: 0.8711 - val_loss: 0.3630 - val_accuracy: 0.8642
# Epoch 23/100
# 168/168 [==============================] - 0s 531us/step - loss: 0.3094 - accuracy: 0.8703 - val_loss: 0.3621 - val_accuracy: 0.8619
# Epoch 24/100
# 168/168 [==============================] - 0s 537us/step - loss: 0.3100 - accuracy: 0.8688 - val_loss: 0.3617 - val_accuracy: 0.8597
# Epoch 25/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3086 - accuracy: 0.8683 - val_loss: 0.3680 - val_accuracy: 0.8642
# Epoch 26/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3090 - accuracy: 0.8694 - val_loss: 0.3667 - val_accuracy: 0.8649
# Epoch 27/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3080 - accuracy: 0.8690 - val_loss: 0.3620 - val_accuracy: 0.8612
# Epoch 28/100
# 168/168 [==============================] - 0s 535us/step - loss: 0.3078 - accuracy: 0.8701 - val_loss: 0.3611 - val_accuracy: 0.8612
# Epoch 29/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3099 - accuracy: 0.8694 - val_loss: 0.3658 - val_accuracy: 0.8530
# Epoch 30/100
# 168/168 [==============================] - 0s 528us/step - loss: 0.3088 - accuracy: 0.8701 - val_loss: 0.3657 - val_accuracy: 0.8522
# Epoch 31/100
# 168/168 [==============================] - 0s 531us/step - loss: 0.3085 - accuracy: 0.8709 - val_loss: 0.3640 - val_accuracy: 0.8582
# Epoch 32/100
# 168/168 [==============================] - 0s 532us/step - loss: 0.3081 - accuracy: 0.8709 - val_loss: 0.3691 - val_accuracy: 0.8485
# Epoch 33/100
# 168/168 [==============================] - 0s 533us/step - loss: 0.3075 - accuracy: 0.8733 - val_loss: 0.3636 - val_accuracy: 0.8612
# Epoch 34/100
# 168/168 [==============================] - 0s 528us/step - loss: 0.3071 - accuracy: 0.8724 - val_loss: 0.3674 - val_accuracy: 0.8507
# Epoch 35/100
# 168/168 [==============================] - 0s 530us/step - loss: 0.3081 - accuracy: 0.8724 - val_loss: 0.3685 - val_accuracy: 0.8582
# Epoch 36/100
# 168/168 [==============================] - 0s 536us/step - loss: 0.3091 - accuracy: 0.8677 - val_loss: 0.3618 - val_accuracy: 0.8627
# Epoch 37/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3079 - accuracy: 0.8724 - val_loss: 0.3614 - val_accuracy: 0.8582
# Epoch 38/100
# 168/168 [==============================] - 0s 528us/step - loss: 0.3087 - accuracy: 0.8677 - val_loss: 0.3653 - val_accuracy: 0.8604
# Epoch 39/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3087 - accuracy: 0.8718 - val_loss: 0.3647 - val_accuracy: 0.8597
# Epoch 40/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3079 - accuracy: 0.8733 - val_loss: 0.3654 - val_accuracy: 0.8597
# Epoch 41/100
# 168/168 [==============================] - 0s 531us/step - loss: 0.3078 - accuracy: 0.8690 - val_loss: 0.3633 - val_accuracy: 0.8590
# Epoch 42/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3076 - accuracy: 0.8698 - val_loss: 0.3670 - val_accuracy: 0.8590
# Epoch 43/100
# 168/168 [==============================] - 0s 523us/step - loss: 0.3066 - accuracy: 0.8713 - val_loss: 0.3646 - val_accuracy: 0.8634
# Epoch 44/100
# 168/168 [==============================] - 0s 524us/step - loss: 0.3076 - accuracy: 0.8711 - val_loss: 0.3680 - val_accuracy: 0.8575
# Epoch 45/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3078 - accuracy: 0.8711 - val_loss: 0.3672 - val_accuracy: 0.8612
# Epoch 46/100
# 168/168 [==============================] - 0s 519us/step - loss: 0.3073 - accuracy: 0.8703 - val_loss: 0.3724 - val_accuracy: 0.8604
# Epoch 47/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3078 - accuracy: 0.8701 - val_loss: 0.3662 - val_accuracy: 0.8582
# Epoch 48/100
# 168/168 [==============================] - 0s 527us/step - loss: 0.3063 - accuracy: 0.8718 - val_loss: 0.3672 - val_accuracy: 0.8590
# Epoch 49/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3080 - accuracy: 0.8701 - val_loss: 0.3700 - val_accuracy: 0.8597
# Epoch 50/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3073 - accuracy: 0.8696 - val_loss: 0.3672 - val_accuracy: 0.8619
# Epoch 51/100
# 168/168 [==============================] - 0s 588us/step - loss: 0.3080 - accuracy: 0.8713 - val_loss: 0.3676 - val_accuracy: 0.8582
# Epoch 52/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3077 - accuracy: 0.8698 - val_loss: 0.3740 - val_accuracy: 0.8590
# Epoch 53/100
# 168/168 [==============================] - 0s 530us/step - loss: 0.3086 - accuracy: 0.8707 - val_loss: 0.3710 - val_accuracy: 0.8560
# Epoch 54/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3075 - accuracy: 0.8677 - val_loss: 0.3655 - val_accuracy: 0.8567
# Epoch 55/100
# 168/168 [==============================] - 0s 534us/step - loss: 0.3072 - accuracy: 0.8681 - val_loss: 0.3657 - val_accuracy: 0.8597
# Epoch 56/100
# 168/168 [==============================] - 0s 523us/step - loss: 0.3068 - accuracy: 0.8705 - val_loss: 0.3664 - val_accuracy: 0.8567
# Epoch 57/100
# 168/168 [==============================] - 0s 531us/step - loss: 0.3071 - accuracy: 0.8707 - val_loss: 0.3616 - val_accuracy: 0.8590
# Epoch 58/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3066 - accuracy: 0.8696 - val_loss: 0.3658 - val_accuracy: 0.8619
# Epoch 59/100
# 168/168 [==============================] - 0s 524us/step - loss: 0.3077 - accuracy: 0.8690 - val_loss: 0.3657 - val_accuracy: 0.8604
# Epoch 60/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3069 - accuracy: 0.8705 - val_loss: 0.3690 - val_accuracy: 0.8597
# Epoch 61/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3067 - accuracy: 0.8696 - val_loss: 0.3725 - val_accuracy: 0.8604
# Epoch 62/100
# 168/168 [==============================] - 0s 522us/step - loss: 0.3082 - accuracy: 0.8700 - val_loss: 0.3665 - val_accuracy: 0.8560
# Epoch 63/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3076 - accuracy: 0.8709 - val_loss: 0.3631 - val_accuracy: 0.8627
# Epoch 64/100
# 168/168 [==============================] - 0s 621us/step - loss: 0.3071 - accuracy: 0.8711 - val_loss: 0.3663 - val_accuracy: 0.8560
# Epoch 65/100
# 168/168 [==============================] - 0s 528us/step - loss: 0.3086 - accuracy: 0.8700 - val_loss: 0.3662 - val_accuracy: 0.8507
# Epoch 66/100
# 168/168 [==============================] - 0s 523us/step - loss: 0.3066 - accuracy: 0.8735 - val_loss: 0.3715 - val_accuracy: 0.8507
# Epoch 67/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3081 - accuracy: 0.8698 - val_loss: 0.3689 - val_accuracy: 0.8590
# Epoch 68/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3074 - accuracy: 0.8713 - val_loss: 0.3661 - val_accuracy: 0.8590
# Epoch 69/100
# 168/168 [==============================] - 0s 523us/step - loss: 0.3069 - accuracy: 0.8694 - val_loss: 0.3664 - val_accuracy: 0.8604
# Epoch 70/100
# 168/168 [==============================] - 0s 531us/step - loss: 0.3068 - accuracy: 0.8698 - val_loss: 0.3655 - val_accuracy: 0.8597
# Epoch 71/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3058 - accuracy: 0.8700 - val_loss: 0.3677 - val_accuracy: 0.8582
# Epoch 72/100
# 168/168 [==============================] - 0s 536us/step - loss: 0.3064 - accuracy: 0.8715 - val_loss: 0.3722 - val_accuracy: 0.8545
# Epoch 73/100
# 168/168 [==============================] - 0s 523us/step - loss: 0.3064 - accuracy: 0.8698 - val_loss: 0.3666 - val_accuracy: 0.8604
# Epoch 74/100
# 168/168 [==============================] - 0s 521us/step - loss: 0.3062 - accuracy: 0.8713 - val_loss: 0.3685 - val_accuracy: 0.8590
# Epoch 75/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3064 - accuracy: 0.8720 - val_loss: 0.3675 - val_accuracy: 0.8560
# Epoch 76/100
# 168/168 [==============================] - 0s 520us/step - loss: 0.3070 - accuracy: 0.8715 - val_loss: 0.3680 - val_accuracy: 0.8567
# Epoch 77/100
# 168/168 [==============================] - 0s 535us/step - loss: 0.3075 - accuracy: 0.8690 - val_loss: 0.3680 - val_accuracy: 0.8575
# Epoch 78/100
# 168/168 [==============================] - 0s 534us/step - loss: 0.3060 - accuracy: 0.8687 - val_loss: 0.3664 - val_accuracy: 0.8582
# Epoch 79/100
# 168/168 [==============================] - 0s 599us/step - loss: 0.3056 - accuracy: 0.8698 - val_loss: 0.3640 - val_accuracy: 0.8582
# Epoch 80/100
# 168/168 [==============================] - 0s 538us/step - loss: 0.3062 - accuracy: 0.8698 - val_loss: 0.3727 - val_accuracy: 0.8567
# Epoch 81/100
# 168/168 [==============================] - 0s 525us/step - loss: 0.3067 - accuracy: 0.8711 - val_loss: 0.3714 - val_accuracy: 0.8530
# Epoch 82/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3069 - accuracy: 0.8701 - val_loss: 0.3719 - val_accuracy: 0.8597
# Epoch 83/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3074 - accuracy: 0.8711 - val_loss: 0.3716 - val_accuracy: 0.8604
# Epoch 84/100
# 168/168 [==============================] - 0s 524us/step - loss: 0.3070 - accuracy: 0.8700 - val_loss: 0.3613 - val_accuracy: 0.8582
# Epoch 85/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3068 - accuracy: 0.8688 - val_loss: 0.3664 - val_accuracy: 0.8590
# Epoch 86/100
# 168/168 [==============================] - 0s 532us/step - loss: 0.3053 - accuracy: 0.8731 - val_loss: 0.3701 - val_accuracy: 0.8545
# Epoch 87/100
# 168/168 [==============================] - 0s 529us/step - loss: 0.3049 - accuracy: 0.8715 - val_loss: 0.3660 - val_accuracy: 0.8590
# Epoch 88/100
# 168/168 [==============================] - 0s 531us/step - loss: 0.3060 - accuracy: 0.8711 - val_loss: 0.3623 - val_accuracy: 0.8597
# Epoch 89/100
# 168/168 [==============================] - 0s 521us/step - loss: 0.3051 - accuracy: 0.8685 - val_loss: 0.3746 - val_accuracy: 0.8597
# Epoch 90/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3058 - accuracy: 0.8713 - val_loss: 0.3664 - val_accuracy: 0.8582
# Epoch 91/100
# 168/168 [==============================] - 0s 528us/step - loss: 0.3054 - accuracy: 0.8696 - val_loss: 0.3653 - val_accuracy: 0.8582
# Epoch 92/100
# 168/168 [==============================] - 0s 523us/step - loss: 0.3065 - accuracy: 0.8700 - val_loss: 0.3676 - val_accuracy: 0.8575
# Epoch 93/100
# 168/168 [==============================] - 0s 521us/step - loss: 0.3066 - accuracy: 0.8700 - val_loss: 0.3758 - val_accuracy: 0.8560
# Epoch 94/100
# 168/168 [==============================] - 0s 530us/step - loss: 0.3055 - accuracy: 0.8701 - val_loss: 0.3694 - val_accuracy: 0.8597
# Epoch 95/100
# 168/168 [==============================] - 0s 516us/step - loss: 0.3049 - accuracy: 0.8701 - val_loss: 0.3699 - val_accuracy: 0.8604
# Epoch 96/100
# 168/168 [==============================] - 0s 530us/step - loss: 0.3074 - accuracy: 0.8698 - val_loss: 0.3728 - val_accuracy: 0.8582
# Epoch 97/100
# 168/168 [==============================] - 0s 526us/step - loss: 0.3053 - accuracy: 0.8688 - val_loss: 0.3705 - val_accuracy: 0.8597
# Epoch 98/100
# 168/168 [==============================] - 0s 520us/step - loss: 0.3048 - accuracy: 0.8718 - val_loss: 0.3650 - val_accuracy: 0.8604
# Epoch 99/100
# 168/168 [==============================] - 0s 527us/step - loss: 0.3050 - accuracy: 0.8696 - val_loss: 0.3677 - val_accuracy: 0.8560
# Epoch 100/100
# 168/168 [==============================] - 0s 527us/step - loss: 0.3052 - accuracy: 0.8688 - val_loss: 0.3741 - val_accuracy: 0.8537

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model2 = Sequential(name = 'model2')
model2.add(Dense(11, activation='leaky_relu',input_dim = 11))
model2.add(BatchNormalization())
model2.add(Dense(1, activation='sigmoid'))

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

history = model.fit(X_train_scaled,y_train, epochs=100, validation_split= 0.2, verbose = False)

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
